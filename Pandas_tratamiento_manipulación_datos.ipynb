# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresCMontejo/Pandas_tratamiento_manipulaci-n_datos/blob/main/Pandas_tratamiento_manipulaci%C3%B3n_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PROBLEMA DE NEGOCIO**

# %% [markdown]
# ###### Se trata de un algoritmo capaz de analizar las caracteristicas de una propiedad -como comodidades, tamaño, ocupación del espacio en un período determinado- y sugerir al anfitrión un precio a cobrar por tarifas diarias que garantice ganancias en momentos de alta demanda.

# %% [markdown]
# ### 1.- Entendiendo el problema

# %%
import pandas as pd

# %%
datos = pd.read_json('/content/drive/MyDrive/ETL/PANDAS/PANDAS I O/datos_hosting.json')
datos.head()
# Out:
#                                       info_inmuebles
# 0  {'evaluacion_general': '10.0', 'experiencia_lo...
# 1  {'evaluacion_general': '10.0', 'experiencia_lo...
# 2  {'evaluacion_general': '10.0', 'experiencia_lo...
# 3  {'evaluacion_general': '10.0', 'experiencia_lo...
# 4  {'evaluacion_general': '10.0', 'experiencia_lo...

# %%
#normalizando
datos = pd.json_normalize(datos['info_inmuebles'])
datos.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --           10
# 2               10.0                --           11
# 3               10.0                --           12
# 4               10.0                --           14
#
#                                    descripcion_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descripcion_vecindad  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    70 non-null     object
#  1   experiencia_local     70 non-null     object
#  2   max_hospedes          70 non-null     object
#  3   descripcion_local     70 non-null     object
#  4   descripcion_vecindad  70 non-null     object
#  5   cantidad_baños        70 non-null     object
#  6   cantidad_cuartos      70 non-null     object
#  7   cantidad_camas        70 non-null     object
#  8   modelo_cama           70 non-null     object
#  9   comodidades           70 non-null     object
#  10  cuota_deposito        70 non-null     object
#  11  cuota_limpieza        70 non-null     object
#  12  precio                70 non-null     object
# dtypes: object(13)
# memory usage: 7.2+ KB

# %% [markdown]
# ## **2.- Datos numericos**

# %%
#Muestra unicamente los nombres de las columnas
columnas = list(datos.columns)
columnas
# Out:
# ['evaluacion_general',
#  'experiencia_local',
#  'max_hospedes',
#  'descripcion_local',
#  'descripcion_vecindad',
#  'cantidad_baños',
#  'cantidad_cuartos',
#  'cantidad_camas',
#  'modelo_cama',
#  'comodidades',
#  'cuota_deposito',
#  'cuota_limpieza',
#  'precio']

# %%
#Explotando las columnas con explode, entre paréntesis() colocamos el filtro de la variable columnas y dentro de corchetes el indie donde queremos iniciar, en este caso
#colocamos [3:] que quiere decir del indice 3 hasta el indice final.
datos = datos.explode(columnas[3:])
datos
#En Python, la función explode() en Pandas se utiliza para transformar una columna de tipo lista,
#tupla, o serie en múltiples filas, expandiendo cada elemento de la estructura iterable en una fila separada.
#Esto facilita el análisis de datos donde la información está anidada en estructuras complejas.
#En pocas palabras, nuestro resultado o tabla que se muestra abajo ya no tiene ninguna lista, todo esta por separado.
# Out:
#    evaluacion_general experiencia_local max_hospedes  \
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# ..                ...               ...          ...
# 68                nan                --            8
# 68                nan                --            8
# 68                nan                --            8
# 69                nan                --            9
# 69                nan                --            9
#
#                                     descripcion_local  \
# 0   This clean and comfortable one bedroom sits ri...
# 0   Our century old Upper Queen Anne house is loca...
# 0   Cozy room in two-bedroom apartment along the l...
# 0   Very lovely and cozy room for one. Convenientl...
# ...

# %%
#Lo siguiente que hay que hacer es resetear el indice, y trabajarlos de forma individual, pues al explotar la tabla., hay
#columnas con listas que ahora ya se independizaron pero conservaron el indice, por eso se repite muchas veces el 0, por lo que
#es necesario resetear el indice de la siguiente manera.
datos.reset_index(inplace=True, drop=True) #drop para borrar el indice anterior.
datos.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --            1
# 2               10.0                --            1
# 3               10.0                --            1
# 4               10.0                --            1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...              1
# 1  Upper Queen Anne is a really pleasant, unique ...              1
# 2  The convenience of being in Seattle but on the...              1
# ...

# %% [markdown]
# #### verificar el tipo de dato, en este caso se observa en la tabla de abajo que todos los tipos de datos son "object", lo cual es una información erronea, ya que si observamos nuestra tabla, tambien tenemos valores enteros y decimales.
# Python suele indicar un valor como "object" cuando no sabe que tipo de valor es.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   object
#  6   cantidad_cuartos      3818 non-null   object
#  7   cantidad_camas        3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
#Resolviendo el problema de tipo de datos.
#Para ello como vamos a trabajar con información numerica, utilizamos "numpy"
import numpy as np

# %%
#A continuación le pedimos a python que cambie el tipo de valor de la columna "max_hospedes" a entero
#Es como decirle al lenguaje, "por favor cambiar el tipo de dato de la columna 'max_hospedes' ya que la libreria pandas
#lo detecta como un 'object' cuando no es un valor de ese tipo"
#Por lo que para modificar ese resultado en nuestra variable "datos", especificamos la columna a la que queremos modificar el tipo de datos
#en este caso es la variable datos, columna 'max_hopedes' en rusumen se ve así --> datos['max_hospedes']
datos['max_hospedes'] = datos['max_hospedes'].astype(np.int64)

# %%
datos.info()
#Ahora al ejecutar la linea, notamos que nuestro tipo de datos en "max_hospedes" es un entero
#OBSERVACIÓN: La linea de .astype(np.int64) no va a funcionar si en nuestra columna hay algun otro valor que no sea entero.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   object
#  6   cantidad_cuartos      3818 non-null   object
#  7   cantidad_camas        3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 387.9+ KB

# %%
#Lo siguiene sería, hacer este cambio en nuestras columnas numericas, para ellos hagamos una lista
col_numericas = ['cantidad_baños', 'cantidad_cuartos', 'cantidad_camas']

# %%
datos[col_numericas] = datos[col_numericas].astype(np.int64)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 387.9+ KB

# %%
datos['evaluacion_general'] = datos['evaluacion_general'].astype(np.float64)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
#esta linea quiere decir: remplaza todo lo que tenga '$' por nada '', y todo lo que tenga "," por nada, más strip significa borrar todo los espacios
datos['precio'] = datos['precio'].apply(lambda x: x.replace('$', '').replace(',', '').strip())

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
datos['precio'] = datos['precio'].astype(np.float64)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 387.9+ KB

# %%
#Cuando trabajamos con dos columnas, para PANDAS esto es un DATAFRAME, si solo estuvieramos modificando una columna, para PANDAS es una serie
#En este caso estamos trabajando con dos columnas, por lo que usamos .applymap para ello
datos[['cuota_deposito', 'cuota_limpieza']] = datos[['cuota_deposito', 'cuota_limpieza']].fillna('0.0').map(lambda x: str(x).replace('$', '').replace(',', '').strip())

# %%
datos[['cuota_deposito', 'cuota_limpieza']] = datos[['cuota_deposito', 'cuota_limpieza']].astype(np.float64)

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   float64
#  11  cuota_limpieza        3818 non-null   float64
#  12  precio                3818 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 387.9+ KB

# %% [markdown]
# ### 3. DATOS DE TEXTO

# %%
#Transformamos en str los textos de la columna, posteriormente usamos .lower() para transformar todo el texto en
#minuscula todo el texto de la columna 'descripcion_loca'
datos['descripcion_local'] = datos['descripcion_local'].str.lower()

# %%
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
#Examinando una unica variable atraves del indice.
datos['descripcion_local'][3169]
# Out:
# "built, run and supported by seattle tech and start up veterans, grokhome's focus is to create a supportive environment for smart people working on interesting projects, start ups and more. this listing is an upper bunk, in a 2-person shared room. *note: this fall, there will be major renovations happening on one kitchen and bathroom at a time. there will always be two other working kitchens and two working bathrooms in the house. we'll work to minimize the impact these renovations have on your stay. **this listing is only available to those working in the tech/science space. live in a hacker house, and immerse yourself in the seattle tech scene. you can expect to be surrounded by smart people solving big problems or working on something fun. we have frequent demo nights, and love when our guests share something they are passionate about. if you're new to the city, our deep ties to the seattle tech scene can help you get involved. expand your network, develop your ideas, and learn so
# ...

# %%
#UTILIZANDO REGEX para reemplazar de una forma más precisa y compleja.
#Utilizar regex, es utilizar la función replace, seguido de lo siguiente: [^a-zA^-Z0-9\-\'], que significa "^" negación, es decir, le estamos
#diciendo a python que de la letra a hasta la z, no elimines nada, de la A a la Z (mayusculas) no eliminar nada, al igual que los guiones y comilla '
#todo lo demas, python lo tendrá que remplazar por espacio.
datos['descripcion_local'] = datos['descripcion_local'].str.replace('[^a-zA-Z0-9\-\']',' ',regex=True)
datos['descripcion_local'][3169]
# Out:
# "built  run and supported by seattle tech and start up veterans  grokhome's focus is to create a supportive environment for smart people working on interesting projects  start ups and more  this listing is an upper bunk  in a 2-person shared room   note  this fall  there will be major renovations happening on one kitchen and bathroom at a time  there will always be two other working kitchens and two working bathrooms in the house  we'll work to minimize the impact these renovations have on your stay    this listing is only available to those working in the tech science space  live in a hacker house  and immerse yourself in the seattle tech scene  you can expect to be surrounded by smart people solving big problems or working on something fun  we have frequent demo nights  and love when our guests share something they are passionate about  if you're new to the city  our deep ties to the seattle tech scene can help you get involved  expand your network  develop your ideas  and learn so
# ...

# %%
#lo siguiente es similar a la linea anterior, '(?<!\w)-(?!\w)' quiere decir que: elimina los guiones que no tienen ningun caracter (letra, simbolos etc) a la izquierda y a lo
#mismo a la derecha y remplaza por un espacio ' '
datos['descripcion_local'] = datos['descripcion_local'].str.replace('(?<!\w)-(?!\w)',' ',regex=True)
datos['descripcion_local'][3169]
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one  convenientl...
# 4  the  studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
#Ahora convertimos nuestros textos de la columna 'descripcion_local' en una lista de caracteres, por ejemplo, supongamos que tenemos un
#hola como estas, y queremos traducirlo de la siguiente forma: ['hola','como','estas'], para ello utilizamos el ".split()", que por si solo
#utiliza por default el caracter del espacio, pues agregara como lista palabras, letras etc, cada que exista un espacio entre ellas.
datos['descripcion_local'] = datos['descripcion_local'].str.split()
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
#Eliminando llaves y comillas dobles en la columna 'comodidades'. '\{|}|\"' le estamos diciendo a python que \ busque la llave de { y "|" ademas busca
#el cierre de la llave --> }, y ademas busca las comillas y todo lo sustituyes por '' nada. el simbolo de | signifa ademas has tal cosa....
datos['comodidades'] = datos['comodidades'].str.replace('\{|}|\"', '', regex=True)
#aun no esta transformado en lista

# %%
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
#transformando en una lista
datos['comodidades'] = datos['comodidades'].str.split(',')
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
datos['descripcion_vecindad'][3444]
# Out:
# 'Very quiet neighborhood with quite wide street.  Friendly place to visit and very walkable.'

# %%
datos['descripcion_vecindad'] = datos['descripcion_vecindad'].str.lower()
datos['descripcion_vecindad'] = datos['descripcion_vecindad'].str.replace('[^a-zA-Z0-9\-\']',' ',regex=True)
datos['descripcion_vecindad'] = datos['descripcion_vecindad'].str.replace('(?<!\w)-(?!\w)',' ',regex=True)
datos['descripcion_vecindad'] = datos['descripcion_vecindad'].str.split()
datos.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  [lower, queen, anne, is, near, the, seattle, c...               1
# 1  [upper, queen, anne, is, a, really, pleasant, ...               1
# 2  [the, convenience, of, being, in, seattle, but...               1
# ...

# %% [markdown]
# ## **DATOS DE TIEMPO**

# %%
dt_data = pd.read_json('/content/drive/MyDrive/ETL/inmuebles_disponibles.json')
dt_data.head()
# Out:
#     id       fecha  lugar_disponible precio
# 0  857  2016-01-04             False   None
# 1  857  2016-01-05             False   None
# 2  857  2016-01-06             False   None
# 3  857  2016-01-07             False   None
# 4  857  2016-01-08             False   None

# %%
dt_data.sample(10)
# Out:
#           id       fecha  lugar_disponible   precio
# 322161  2867  2016-08-22              True  $150.00
# 80716   2927  2016-02-24             False     None
# 123602  3686  2016-08-23              True  $195.00
# 113551  2386  2016-02-09              True   $58.00
# 132580  2150  2016-03-29              True  $182.00
# 19330   3092  2016-12-19              True   $65.00
# 18490    678  2016-08-31              True  $110.00
# 329077  2705  2016-08-03             False     None
# 346647  3213  2016-09-22              True   $40.00
# 276332  2410  2016-01-31             False     None

# %%
#Nuestra fecha aparece como tipo "objetc", por lo que tenemos que transformarlo a tiempo
#para transformar a tipo "tiempo", llamamos a panda con pd a.., datetime entre los parentesis agregamos la variable, seguido de los corchetes
#agregamos el nombre de la columna.
dt_data['fecha'] = pd.to_datetime(dt_data['fecha'])
#ADVERTENCIA: Si queremos que esta linea funcione, solo tiene que tener información de FECHAS.
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
dt_data.head()
# Out:
#     id      fecha  lugar_disponible precio
# 0  857 2016-01-04             False   None
# 1  857 2016-01-05             False   None
# 2  857 2016-01-06             False   None
# 3  857 2016-01-07             False   None
# 4  857 2016-01-08             False   None

# %%
#En la tabla anterior nos muestra las fechas con el siguiente formato Año(Y), mes(m) y día(d).
#Podemos filtrar y que solo nos muestre por ejemplo, el año y el mes.
dt_data['fecha'].dt.strftime('%Y-%m') #dt significa la función datetime, agregamos el guión entre %Y y %m para conservar el formato de la tabla original
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 364995    2016-12
# 364996    2016-12
# 364997    2016-12
# 364998    2017-01
# 364999    2017-01
# Name: fecha, Length: 365000, dtype: object

# %%
#El codigo anterior nos mostró el filtro de año y mes, ahora queremos saber cuantos lugares por mes y año habían disponibles, para ello necesitamos
#agrupar dos columnas, es decir, decirle a python, cuenta cuantos valores "true" hay en la columna "lugar_disponible", y sumalas con respecto a las fechas filtradas por año y mes
subset = dt_data.groupby(dt_data['fecha'].dt.strftime('%Y-%m'))['lugar_disponible'].sum() #por default sumara los valores boolenos "true"
subset
# Out:
# fecha
# 2016-01    16543
# 2016-02    20128
# 2016-03    23357
# 2016-04    22597
# 2016-05    23842
# 2016-06    23651
# 2016-07    22329
# 2016-08    22529
# 2016-09    22471
# 2016-10    23765
# 2016-11    23352
# 2016-12    24409
# 2017-01     1574
# Name: lugar_disponible, dtype: int64

# %%
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
import numpy as np
dt_data['precio'].fillna('0.0')
dt_data['precio'] = dt_data['precio'].apply(lambda x: str(x).replace('$', '').replace(',',''))
dt_data['precio'] = dt_data['precio'].replace('None', '0.0')  # en caso de que haya strings 'None'
dt_data['precio'] = pd.to_numeric(dt_data['precio'], errors='coerce').fillna(0.0)
dt_data['precio'] = dt_data['precio'].astype(np.float64)
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            365000 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 11.5 MB

# %%
#OTRA FORMA DE HACERLO
'''
import numpy as np
dt_data['precio'] = dt_data['precio'].fillna('0.0')
dt_data['precio'] = dt_data['precio'].astype(str).str.replace('$', '').str.replace(',', '')
dt_data['precio'] = dt_data['precio'].replace('None', '0.0')  # en caso de que haya strings 'None'
dt_data['precio'] = pd.to_numeric(dt_data['precio'], errors='coerce').fillna(0.0)
dt_data.info()
'''
# Out:
# "\nimport numpy as np\ndt_data['precio'] = dt_data['precio'].fillna('0.0')\ndt_data['precio'] = dt_data['precio'].astype(str).str.replace('$', '').str.replace(',', '')\ndt_data['precio'] = dt_data['precio'].replace('None', '0.0')  # en caso de que haya strings 'None'\ndt_data['precio'] = pd.to_numeric(dt_data['precio'], errors='coerce').fillna(0.0)\ndt_data.info()\n"

# %%
dt_data.sample(10)
# Out:
#           id      fecha  lugar_disponible  precio
# 222773  1036 2016-05-06              True    79.0
# 15306   3594 2016-12-10              True   165.0
# 359306  3639 2016-05-29              True    80.0
# 351186    97 2016-02-29              True    75.0
# 97584   3321 2016-05-12             False     0.0
# 303776   982 2016-04-09             False     0.0
# 7801    1754 2016-05-19              True   137.0
# 207514   909 2016-07-16              True   150.0
# 226042   617 2016-04-20              True    89.0
# 30268   1046 2016-12-07              True    82.0
